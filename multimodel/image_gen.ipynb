# %%
from decouple import config
from google.genai import types
from PIL import Image
from io import BytesIO
from google import genai

# %%
GOOGLE_API_KEY = config("GOOGLE_API_KEY")
client = genai.Client(
    api_key=GOOGLE_API_KEY,
)

# %%
prompt = (
    "Create a picture of a futuristic robot holding a red skateboard, cinematic lighting"
)

response = client.models.generate_content(
    model="gemini-2.0-flash",
    contents=[prompt],
)

for part in response.candidates[0].content.parts:
    if part.text is not None:
        print(part.text)
    elif part.inline_data is not None:
        image = Image.open(BytesIO(part.inline_data.data))
        image.save("generated_image.png")
# Out:
# This query is a good fit for an image generation model. Here's a breakdown of how I would approach creating the image and a description of the final result:
#
# **Concept Breakdown:**
#
# *   **Subject:** Futuristic Robot
#     *   Sleek design, potentially humanoid but with distinct robotic features (glowing elements, intricate paneling, exposed wires in some areas, not overly clunky).
#     *   Material: Mixture of polished metal (aluminum, chrome), matte black sections, maybe some translucent or glowing parts.
# *   **Action:** Holding a Red Skateboard
#     *   The robot is actively holding the skateboard. Not leaning against it or just next to it. It should grip the board firmly but not aggressively.  Consider posing options: casually holding it by the trucks, under its arm, or balancing it on its shoulder.
#     *   Red skateboard: A classic color that contrasts well against metallic surfaces. Visible grip tape, possibly some worn graphics.
# *   **Setting/Environment:**
#     *   Ambiguous, slightly gritty, urban background. Could be an alleyway, an abandoned warehouse, a city rooftop at night.  Dark and moody, but not completely black. Suggests an area where skateboarding might happen.
# *   **Lighting:** Cinematic
#     *   Dramatic lighting is key. Strong directional light source (e.g., a spotlight or the moon).
#     *   Emphasis on shadows and highlights to define the robot's form.
#     *   Rim light to separate the robot from the background.
#     *   Possible light bloom/lens flares around glowing elements (if any).
#     *   Color temperature: A cool, slightly desaturated color palette with the red skateboard providing a vibrant pop of color.
#
# **Generated Image Description:**
#
# The image depicts a sleek, futuristic robot standing in a dimly lit urban alleyway. The robot is primarily constructed from polished aluminum and matte black composite materials, giving it a modern and advanced appearance. Subtle blue glowing accents illuminate its chest and eye sockets. Its design is humanoid but distinctly robotic, with visible joints and detailed paneling. It is holding a vibrant red skateboard under its right arm.
#
# The alleyway is dark and gritty, with brick walls and graffiti in the background. The ground is wet, reflecting the dim ambient light. A single spotlight from above casts a dramatic beam across the robot, highlighting its metallic surfaces and creating long, defined shadows. A subtle rim light from the left separates the robot from the background, emphasizing its silhouette.
#
# The overall tone is cinematic and slightly melancholic. The cool color palette, combined with the stark lighting and urban setting, creates a sense of mystery and technological advancement. The bright red skateboard adds a touch of rebellious energy to the scene. Lens flares and light bloom are subtly applied around the robot's glowing elements, enhancing the sense of realism and cinematic quality.
